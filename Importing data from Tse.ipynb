# %%
#!pip install pytse_client

# %%
import pytse_client as tse
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = tse.download(symbols=["وبملت", "کچاد"],include_jdate= True,)

# %%
df=data['کچاد']

# %%
#additional information
ticker = tse.Ticker("کچاد")
print(ticker.group_name)
# Out:
# استخراج كانه هاي فلزي

# %%
type(df),type(data)
# Out:
# (pandas.core.frame.DataFrame, dict)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3956 entries, 0 to 3955
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       3956 non-null   datetime64[ns]
#  1   open       3956 non-null   float64
#  2   high       3956 non-null   float64
#  3   low        3956 non-null   float64
#  4   adjClose   3956 non-null   float64
#  5   value      3956 non-null   int64
#  6   volume     3956 non-null   int64
#  7   count      3956 non-null   int64
#  8   yesterday  3956 non-null   float64
#  9   close      3956 non-null   float64
#  10  jdate      3956 non-null   object
# dtypes: datetime64[ns](1), float64(6), int64(3), object(1)
# memory usage: 340.1+ KB

# %%
#saving data as needed
#df.to_csv('chador.csv')

# %%
df['open'].plot()
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#            date     open     high      low  adjClose         value    volume  \
# 0    2003-10-19   2991.0   2991.0   2900.0    2916.0    5833615016   2000000
# 1    2003-10-20   3061.0   3061.0   3061.0    3061.0   22957500000   7500000
# 2    2003-10-21   3214.0   3214.0   3214.0    3214.0   19284000000   6000000
# 3    2003-10-22   3374.0   3374.0   3374.0    3374.0   10122000000   3000000
# 4    2003-10-25   3542.0   3542.0   3542.0    3542.0   33039067600   9327800
# ...         ...      ...      ...      ...       ...           ...       ...
# 3951 2022-04-20  15910.0  16160.0  15810.0   15980.0  163217185830  10212763
# 3952 2022-04-24  16070.0  16080.0  15670.0   15910.0   95200371760   5990000
# 3953 2022-04-25  15860.0  16180.0  15750.0   15960.0   65204028420   4075552
# 3954 2022-04-26  16000.0  16170.0  15900.0   15970.0  104425678190   6539318
# 3955 2022-04-27  16070.0  16070.0  15820.0   15930.0   72035615690   4528143
#
#       count  yesterday    close       jdate
# ...

# %%
df['date'] =  pd.to_datetime(df['date'], infer_datetime_format=True)

# %%
#df.set_index('date',inplace=True)

# %%
plt.scatter(x=df.index[-15:] , y=df.open[-15:] )

# %%
df['new']=df['open'].shift(periods=3)

# %%
df
# Out:
#            date     open     high      low  adjClose         value   volume  \
# 0    2003-10-19   2991.0   2991.0   2900.0    2916.0    5833615016  2000000
# 1    2003-10-20   3061.0   3061.0   3061.0    3061.0   22957500000  7500000
# 2    2003-10-21   3214.0   3214.0   3214.0    3214.0   19284000000  6000000
# 3    2003-10-22   3374.0   3374.0   3374.0    3374.0   10122000000  3000000
# 4    2003-10-25   3542.0   3542.0   3542.0    3542.0   33039067600  9327800
# ...         ...      ...      ...      ...       ...           ...      ...
# 3911 2022-02-07  29150.0  29870.0  29010.0   29200.0   49884445020  1705522
# 3912 2022-02-08  29690.0  29890.0  29030.0   29580.0  112509287780  3800062
# 3913 2022-02-09  30000.0  30000.0  29410.0   29620.0   52042600390  1754238
# 3914 2022-02-12  29220.0  30000.0  29220.0   29660.0   41688325070  1401533
# 3915 2022-02-13  29960.0  30000.0  29000.0   29690.0   51292950580  1725293
#
#       count  yesterday    close       jdate      new
# ...
