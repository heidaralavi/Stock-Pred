# %%
#!pip install pytse_client

# %%
import pytse_client as tse
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = tse.download(symbols=["وبملت", "کچاد"])

# %%
df=data['کچاد']

# %%
type(df),type(data)
# Out:
# (pandas.core.frame.DataFrame, dict)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3915 entries, 0 to 3914
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       3915 non-null   datetime64[ns]
#  1   open       3915 non-null   float64
#  2   high       3915 non-null   float64
#  3   low        3915 non-null   float64
#  4   adjClose   3915 non-null   float64
#  5   value      3915 non-null   int64
#  6   volume     3915 non-null   int64
#  7   count      3915 non-null   int64
#  8   yesterday  3915 non-null   float64
#  9   close      3915 non-null   float64
# dtypes: datetime64[ns](1), float64(6), int64(3)
# memory usage: 306.0 KB

# %%
#df.to_csv('chador.csv')

# %%
df['open'].plot()
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#            date     open     high      low  adjClose         value   volume  \
# 0    2003-10-19   2991.0   2991.0   2900.0    2916.0    5833615016  2000000
# 1    2003-10-20   3061.0   3061.0   3061.0    3061.0   22957500000  7500000
# 2    2003-10-21   3214.0   3214.0   3214.0    3214.0   19284000000  6000000
# 3    2003-10-22   3374.0   3374.0   3374.0    3374.0   10122000000  3000000
# 4    2003-10-25   3542.0   3542.0   3542.0    3542.0   33039067600  9327800
# ...         ...      ...      ...      ...       ...           ...      ...
# 3910 2022-02-06  29950.0  29950.0  28210.0   29160.0  143320376550  4915291
# 3911 2022-02-07  29150.0  29870.0  29010.0   29200.0   49884445020  1705522
# 3912 2022-02-08  29690.0  29890.0  29030.0   29580.0  112509287780  3800062
# 3913 2022-02-09  30000.0  30000.0  29410.0   29620.0   52042600390  1754238
# 3914 2022-02-12  29220.0  30000.0  29220.0   29660.0   41688325070  1401533
#
#       count  yesterday    close
# 0       667        0.0   2916.0
# 1      1277     2916.0   3061.0
# 2      1102     3061.0   3214.0
# 3       670     3214.0   3374.0
# 4      1540     3374.0   3542.0
# ...     ...        ...      ...
# 3910   1353    29610.0  28420.0
# 3911    853    29160.0  29200.0
# 3912    694    29200.0  29570.0
# 3913    891    29580.0  29660.0
# 3914    704    29620.0  29650.0
#
# [3915 rows x 10 columns]

# %%
df['date'] =  pd.to_datetime(df['date'], infer_datetime_format=True)

# %%
df.set_index('date',inplace=True)

# %%
df['open'].plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df['new']=df['open'].shift(periods=3)

# %%
df
# Out:
#                open     high      low  adjClose         value   volume  count  \
# date
# 2003-10-19   2991.0   2991.0   2900.0    2916.0    5833615016  2000000    667
# 2003-10-20   3061.0   3061.0   3061.0    3061.0   22957500000  7500000   1277
# 2003-10-21   3214.0   3214.0   3214.0    3214.0   19284000000  6000000   1102
# 2003-10-22   3374.0   3374.0   3374.0    3374.0   10122000000  3000000    670
# 2003-10-25   3542.0   3542.0   3542.0    3542.0   33039067600  9327800   1540
# ...             ...      ...      ...       ...           ...      ...    ...
# 2022-02-06  29950.0  29950.0  28210.0   29160.0  143320376550  4915291   1353
# 2022-02-07  29150.0  29870.0  29010.0   29200.0   49884445020  1705522    853
# 2022-02-08  29690.0  29890.0  29030.0   29580.0  112509287780  3800062    694
# 2022-02-09  30000.0  30000.0  29410.0   29620.0   52042600390  1754238    891
# 2022-02-12  29220.0  30000.0  29220.0   29660.0   41688325070  1401533    704
#
#             yesterday    close      new
# date
# 2003-10-19        0.0   2916.0      NaN
# 2003-10-20     2916.0   3061.0      NaN
# 2003-10-21     3061.0   3214.0      NaN
# 2003-10-22     3214.0   3374.0   2991.0
# 2003-10-25     3374.0   3542.0   3061.0
# ...               ...      ...      ...
# 2022-02-06    29610.0  28420.0  29910.0
# 2022-02-07    29160.0  29200.0  29350.0
# 2022-02-08    29200.0  29570.0  30000.0
# 2022-02-09    29580.0  29660.0  29950.0
# 2022-02-12    29620.0  29650.0  29150.0
#
# [3915 rows x 10 columns]
