# %%
#!pip install tensorflow
#!pip install keras

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM ,Dense ,Dropout

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
import pickle

# %%
# %matplotlib inline

# %%
df = pd.read_csv('Chad.csv')

# %%
df.sort_index(axis=0,inplace=True,ascending=False)

# %%
df,df.shape
# Out:
# (          Date   Open   High    low  Close   Volume
#  3913  20031019   2991   2991   2900   2916  2000000
#  3912  20031020   3061   3061   3061   3061  7500000
#  3911  20031021   3214   3214   3214   3214  6000000
#  3910  20031022   3374   3374   3374   3374  3000000
#  3909  20031025   3542   3542   3542   3542  9327800
#  ...        ...    ...    ...    ...    ...      ...
#  4     20220205  30000  30240  29560  29610  5515311
#  3     20220206  29950  29950  28210  29160  4915291
#  2     20220207  29150  29870  29010  29200  1705522
#  1     20220208  29690  29890  29030  29580  3800062
#  0     20220209  30000  30000  29410  29620  1754238
#
#  [3914 rows x 6 columns],
#  (3914, 6))

# %%
data=df.iloc[:,1:2].values
data.shape
# Out:
# (3914, 1)

# %%
scaler=MinMaxScaler(feature_range=(0,1))

# %%
data_norm = scaler.fit_transform(data)

# %%
X=[]
y=[]
for i in range(60,data_norm.shape[0]):
    X.append(data_norm[i-60:i,0])
    y.append(data_norm[i,0])
X = np.array(X)
y = np.array(y).reshape(-1,1)

# %%
X.shape,y.shape
# Out:
# ((3854, 60), (3854, 1))

# %%
n=int(X.shape[0]*0.9)
X_train,X_test,y_train,y_test=X[:n,:],X[n:,:],y[:n],y[n:]

# %%
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((3468, 60), (3468, 1), (386, 60), (386, 1))

# %%
reg = Sequential()
reg.add(LSTM(units=64,return_sequences=True,input_shape=(X_train.shape[1],1)))
reg.add(Dropout(0.2))

reg.add(LSTM(units=64,return_sequences=True))
reg.add(Dropout(0.2))

reg.add(LSTM(units=64,return_sequences=True))
reg.add(Dropout(0.2))

reg.add(LSTM(units=64,return_sequences=True))
reg.add(Dropout(0.2))

reg.add(LSTM(units=64,return_sequences=True))
reg.add(Dropout(0.2))

reg.add(LSTM(units=64))
reg.add(Dropout(0.2))

reg.add(Dense(units=1))

# %%
reg.compile(optimizer='adam',loss='mean_squared_error')
reg.fit(X_train,y_train,epochs=2,batch_size=64)
# Out:
# Epoch 1/2
# 55/55 [==============================] - 20s 201ms/step - loss: 0.0061
# Epoch 2/2
# 55/55 [==============================] - 12s 218ms/step - loss: 0.0023

# %%
y_pred_train=reg.predict(X_train)

# %%
print("R2 Score for traning: {:.2f}%".format(r2_score(y_train,y_pred_train)*100))
# Out:
# R2 Score for traning: 88.72%

# %%
plt.figure(figsize=(14,10))
plt.plot(range(39),y_train[-40:-1], color = "green")
plt.plot(range(39),y_pred_train[-40:-1], color = "red")
plt.legend(["Actual","prediction"]) 
plt.title("Predicted vs True Value in learning procces")
plt.xlabel("Record number")

plt.show()

# %%
y_pred=reg.predict(X_test)

# %%
y_pred.shape
# Out:
# (386, 1)

# %%
print("R2 Score: {:.2f}%".format(r2_score(y_test,y_pred)*100))
# Out:
# R2 Score: -176.39%

# %%
plt.figure(figsize=(14,10))
plt.plot(range(39),y_test[-40:-1], color = "green")
plt.plot(range(39),y_pred[-40:-1], color = "red")
plt.legend(["Actual","prediction"]) 
plt.title("Predicted vs True Value")
plt.xlabel("Record number")

plt.show()

# %%
plt.figure(figsize=(14,10))
plt.plot(range(len(y_test)),y_test, color = "green")
plt.plot(range(len(y_pred)),y_pred, color = "red")
plt.legend(["Actual","prediction"]) 
plt.title("Predicted vs True Value")
plt.xlabel("Record number")

plt.show()

# %%
reg.compile(optimizer='adam',loss='mean_squared_error')
reg.fit(X,y,epochs=30,batch_size=64)
# Out:
# Epoch 1/30
# 61/61 [==============================] - 22s 222ms/step - loss: 0.0039
# Epoch 2/30
# 61/61 [==============================] - 14s 224ms/step - loss: 0.0031
# Epoch 3/30
# 61/61 [==============================] - 14s 223ms/step - loss: 0.0027
# Epoch 4/30
# 61/61 [==============================] - 14s 223ms/step - loss: 0.0023
# Epoch 5/30
# 61/61 [==============================] - 14s 226ms/step - loss: 0.0021
# Epoch 6/30
# 61/61 [==============================] - 14s 223ms/step - loss: 0.0025
# Epoch 7/30
# 61/61 [==============================] - 14s 231ms/step - loss: 0.0018
# Epoch 8/30
# 61/61 [==============================] - 14s 226ms/step - loss: 0.0016
# Epoch 9/30
# 61/61 [==============================] - 14s 238ms/step - loss: 0.0016
# Epoch 10/30
# 61/61 [==============================] - 14s 230ms/step - loss: 0.0016
# Epoch 11/30
# 61/61 [==============================] - 14s 228ms/step - loss: 0.0015
# Epoch 12/30
# 61/61 [==============================] - 14s 228ms/step - loss: 0.0014
# Epoch 13/30
# 61/61 [==============================] - 14s 228ms/step - loss: 0.0013
# Epoch 14/30
# 61/61 [==============================] - 14s 230ms/step - loss: 0.0014
# Epoch 15/30
# 61/61 [==============================] - 14s 230ms/step - loss: 0.0013
# Epoch 16/30
# 61/61 [==============================] - 14s 232ms/step - loss: 0.0012
# Epoch 17/30
# 61/61 [==============================] - 14s 229ms/step - loss: 0.0012
# Epoch 18/30
# 61/61 [==============================] - 14s 232ms/step - loss: 0.0012
# Epoch 19/30
# 61/61 [==============================] - 14s 226ms/step - loss: 0.0011
# Epoch 20/30
# 61/61 [==============================] - 14s 228ms/step - loss: 0.0011
# Epoch 21/30
# 61/61 [==============================] - 14s 227ms/step - loss: 9.4240e-04
# Epoch 22/30
# 61/61 [==============================] - 14s 229ms/step - loss: 9.5950e-04
# Epoch 23/30
# 61/61 [==============================] - 14s 226ms/step - loss: 9.7960e-04
# Epoch 24/30
# 61/61 [==============================] - 14s 227ms/step - loss: 9.1197e-04
# Epoch 25/30
# 61/61 [==============================] - 14s 229ms/step - loss: 0.0011
# Epoch 26/30
# 61/61 [==============================] - 14s 227ms/step - loss: 0.0010
# Epoch 27/30
# 61/61 [==============================] - 14s 224ms/step - loss: 8.9098e-04
# Epoch 28/30
# 61/61 [==============================] - 14s 225ms/step - loss: 8.6807e-04
# Epoch 29/30
# 61/61 [==============================] - 14s 226ms/step - loss: 9.9894e-04
# Epoch 30/30
# 61/61 [==============================] - 14s 225ms/step - loss: 9.5413e-04

# %%
data_new=data_norm
for i in range(15):
    X_60 = data_new[-60:]
    X_60=np.reshape(X_60,(1,-1))
    y_pred=reg.predict(X_60)
    data_new=np.append(data_new,y_pred)

# %%
data_norm.shape,data_new.shape
# Out:
# ((3914, 1), (3929,))

# %%
X1=data_norm[-30:]
X2=data_new[-45:]
plt.figure(figsize=(14,10))
plt.plot(range(len(X1)),X1, color = "green")
plt.plot(range(len(X2)),X2, color = "red")
plt.legend(["Actual","prediction"]) 
plt.title("Predicted vs True Value")
plt.xlabel("Record number")

plt.show()

# %%
import pickle
filename = 'finalized_model.sav'
pickle.dump(reg, open(filename, 'wb'))
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses, lstm_cell_7_layer_call_fn, lstm_cell_7_layer_call_and_return_conditional_losses, lstm_cell_8_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ram://ffeb50d5-87d9-482c-acf0-a79e03eace16/assets
# INFO:tensorflow:Assets written to: ram://ffeb50d5-87d9-482c-acf0-a79e03eace16/assets
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x0000022F97D23CA0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x0000022F97AC2520> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x0000022F98259640> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x0000022F9824FC10> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x0000022F989AAD60> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x0000022F98A1FDF0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
#model = pickle.load(open(filename, 'rb'))
