# %%
#!pip install pytse_client

# %%
import pytse_client as tse
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\H03C7~1.ALA\AppData\Local\Temp/ipykernel_20824/4016477508.py in <module>
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
# ----> 4 import mplfinance as mpf
#
# ModuleNotFoundError: No module named 'mplfinance'

# %%
#Download data from TSE Site
data = tse.download(symbols=["کچاد"],include_jdate= True,adjust = False) #adjust = True :قیمت تعدیل یافته سهم

# %%
df=data['کچاد']

# %%
type(df),type(data)
# Out:
# (pandas.core.frame.DataFrame, dict)

# %%
df.describe()
# Out:
#                open          high           low      adjClose         value  \
# count   3916.000000   3916.000000   3916.000000   3916.000000  3.916000e+03
# mean    8204.745403   8323.470633   8070.931818   8208.830695  5.155420e+10
# std     6140.129314   6260.869696   6023.919548   6131.596263  1.463998e+11
# min     1446.000000   1476.000000   1434.000000   1469.000000  2.420000e+04
# 25%     4650.750000   4709.750000   4580.000000   4674.250000  2.033525e+09
# 50%     6399.500000   6468.500000   6309.500000   6395.000000  7.112255e+09
# 75%     9647.250000   9700.000000   9499.250000   9585.250000  3.059203e+10
# max    31400.000000  31660.000000  30980.000000  31220.000000  2.520421e+12
#
#              volume         count     yesterday         close
# count  3.916000e+03   3916.000000   3916.000000   3916.000000
# mean   5.233240e+06    737.675434   8194.352400   8192.155005
# std    1.126229e+07   1525.927243   6122.285425   6139.733295
# min    1.000000e+01      1.000000      0.000000   1446.000000
# 25%    3.496678e+05    101.000000   4653.000000   4638.000000
# 50%    1.255268e+06    233.500000   6394.000000   6383.000000
# 75%    5.014622e+06    676.250000   9582.250000   9585.250000
# max    2.270000e+08  31506.000000  31220.000000  31300.000000

# %%
#Tenkan Sen
tenkan_max = df['high'].rolling(window = 9, min_periods = 0).max()
tenkan_min = df['low'].rolling(window = 9, min_periods = 0).min()
df['tenkan_avg'] = (tenkan_max + tenkan_min) / 2

# %%
#Kijun Sen
kijun_max = df['high'].rolling(window = 26, min_periods = 0).max()
kijun_min = df['low'].rolling(window = 26, min_periods = 0).min()
df['kijun_avg'] = (kijun_max + kijun_min) / 2

# %%
#Senkou Span A
#(Kijun + Tenkan) / 2 Shifted ahead by 26 periods
df['senkou_a'] = ((df['kijun_avg'] + df['tenkan_avg']) / 2).shift(26)

# %%
#Senkou Span B
#52 period High + Low / 2
senkou_b_max = df['high'].rolling(window = 52, min_periods = 0).max()
senkou_b_min = df['low'].rolling(window = 52, min_periods = 0).min()
df['senkou_b'] = ((senkou_b_max + senkou_b_min) / 2).shift(52)

# %%
#Chikou Span
#Current close shifted -26
df['chikou'] = (df['close']).shift(-26)

# %%
df.head()
# Out:
#         date    open    high     low  adjClose        value   volume  count  \
# 0 2003-10-19  2991.0  2991.0  2900.0    2916.0   5833615016  2000000    667
# 1 2003-10-20  3061.0  3061.0  3061.0    3061.0  22957500000  7500000   1277
# 2 2003-10-21  3214.0  3214.0  3214.0    3214.0  19284000000  6000000   1102
# 3 2003-10-22  3374.0  3374.0  3374.0    3374.0  10122000000  3000000    670
# 4 2003-10-25  3542.0  3542.0  3542.0    3542.0  33039067600  9327800   1540
#
#    yesterday   close       jdate  tenkan_avg  kijun_avg  senkou_a  senkou_b  \
# 0        0.0  2916.0  1382-07-27      2945.5     2945.5       NaN       NaN
# 1     2916.0  3061.0  1382-07-28      2980.5     2980.5       NaN       NaN
# 2     3061.0  3214.0  1382-07-29      3057.0     3057.0       NaN       NaN
# 3     3214.0  3374.0  1382-07-30      3137.0     3137.0       NaN       NaN
# 4     3374.0  3542.0  1382-08-03      3221.0     3221.0       NaN       NaN
#
#    chikou
# 0  5077.0
# 1  5096.0
# 2  5350.0
# 3  5617.0
# 4  5897.0

# %%
#Plotting Ichimoku
tmp = df[['close','senkou_a','senkou_b','kijun_avg','tenkan_avg']].tail(200)
fig,ax = plt.subplots(1,1,sharex=True,figsize = (20,9)) #share x axis and set a figure size
ax.plot(tmp,label=tmp.columns,linewidth=4) # plot Close with index on x-axis with a line thickness of 4
ax.fill_between(tmp.index, tmp.senkou_a, tmp.senkou_b)
ax.legend()
